# %%
from rdflib import Graph, Namespace, RDF, RDFS, OWL, XSD, URIRef, Literal

# Create a new RDF graph
g = Graph()

# Define namespaces
EX = Namespace("http://example.org/dogbreed#")
g.bind("ex", EX)
g.bind("rdf", RDF)
g.bind("rdfs", RDFS)
g.bind("owl", OWL)
g.bind("xsd", XSD)

# Define Classes
g.add((EX.DogBreed, RDF.type, OWL.Class))
g.add((EX.Biomarker, RDF.type, OWL.Class))
g.add((EX.Disease, RDF.type, OWL.Class))
g.add((EX.Temperament, RDF.type, OWL.Class))
g.add((EX.BreedGroup, RDF.type, OWL.Class))
g.add((EX.DogIndividual, RDF.type, OWL.Class))

# Define Object Properties
g.add((EX.hasTemperament, RDF.type, OWL.ObjectProperty))
g.add((EX.hasTemperament, RDFS.domain, EX.DogBreed))
g.add((EX.hasTemperament, RDFS.range, EX.Temperament))

g.add((EX.belongsToGroup, RDF.type, OWL.ObjectProperty))
g.add((EX.belongsToGroup, RDFS.domain, EX.DogBreed))
g.add((EX.belongsToGroup, RDFS.range, EX.BreedGroup))

g.add((EX.hasBiomarker, RDF.type, OWL.ObjectProperty))
g.add((EX.hasBiomarker, RDFS.domain, EX.DogBreed))
g.add((EX.hasBiomarker, RDFS.range, EX.Biomarker))

g.add((EX.associatedWithDisease, RDF.type, OWL.ObjectProperty))
g.add((EX.associatedWithDisease, RDFS.domain, EX.Biomarker))
g.add((EX.associatedWithDisease, RDFS.range, EX.Disease))

g.add((EX.instanceOfBreed, RDF.type, OWL.ObjectProperty))
g.add((EX.instanceOfBreed, RDFS.domain, EX.DogIndividual))
g.add((EX.instanceOfBreed, RDFS.range, EX.DogBreed))

# Define Data Properties
g.add((EX.breedName, RDF.type, OWL.DatatypeProperty))
g.add((EX.breedName, RDFS.domain, EX.DogBreed))
g.add((EX.breedName, RDFS.range, XSD.string))

g.add((EX.description, RDF.type, OWL.DatatypeProperty))
g.add((EX.description, RDFS.domain, EX.DogBreed))
g.add((EX.description, RDFS.range, XSD.string))

g.add((EX.popularity, RDF.type, OWL.DatatypeProperty))
g.add((EX.popularity, RDFS.domain, EX.DogBreed))
g.add((EX.popularity, RDFS.range, XSD.integer))

g.add((EX.minHeight, RDF.type, OWL.DatatypeProperty))
g.add((EX.minHeight, RDFS.domain, EX.DogBreed))
g.add((EX.minHeight, RDFS.range, XSD.float))

g.add((EX.maxHeight, RDF.type, OWL.DatatypeProperty))
g.add((EX.maxHeight, RDFS.domain, EX.DogBreed))
g.add((EX.maxHeight, RDFS.range, XSD.float))

g.add((EX.minWeight, RDF.type, OWL.DatatypeProperty))
g.add((EX.minWeight, RDFS.domain, EX.DogBreed))
g.add((EX.minWeight, RDFS.range, XSD.float))

g.add((EX.maxWeight, RDF.type, OWL.DatatypeProperty))
g.add((EX.maxWeight, RDFS.domain, EX.DogBreed))
g.add((EX.maxWeight, RDFS.range, XSD.float))

g.add((EX.minExpectancy, RDF.type, OWL.DatatypeProperty))
g.add((EX.minExpectancy, RDFS.domain, EX.DogBreed))
g.add((EX.minExpectancy, RDFS.range, XSD.float))

g.add((EX.maxExpectancy, RDF.type, OWL.DatatypeProperty))
g.add((EX.maxExpectancy, RDFS.domain, EX.DogBreed))
g.add((EX.maxExpectancy, RDFS.range, XSD.float))

g.add((EX.groomingFrequencyValue, RDF.type, OWL.DatatypeProperty))
g.add((EX.groomingFrequencyValue, RDFS.domain, EX.DogBreed))
g.add((EX.groomingFrequencyValue, RDFS.range, XSD.float))

g.add((EX.groomingFrequencyCategory, RDF.type, OWL.DatatypeProperty))
g.add((EX.groomingFrequencyCategory, RDFS.domain, EX.DogBreed))
g.add((EX.groomingFrequencyCategory, RDFS.range, XSD.string))

g.add((EX.sheddingValue, RDF.type, OWL.DatatypeProperty))
g.add((EX.sheddingValue, RDFS.domain, EX.DogBreed))
g.add((EX.sheddingValue, RDFS.range, XSD.float))

g.add((EX.sheddingCategory, RDF.type, OWL.DatatypeProperty))
g.add((EX.sheddingCategory, RDFS.domain, EX.DogBreed))
g.add((EX.sheddingCategory, RDFS.range, XSD.string))

g.add((EX.energyLevelValue, RDF.type, OWL.DatatypeProperty))
g.add((EX.energyLevelValue, RDFS.domain, EX.DogBreed))
g.add((EX.energyLevelValue, RDFS.range, XSD.float))

g.add((EX.energyLevelCategory, RDF.type, OWL.DatatypeProperty))
g.add((EX.energyLevelCategory, RDFS.domain, EX.DogBreed))
g.add((EX.energyLevelCategory, RDFS.range, XSD.string))

g.add((EX.trainabilityValue, RDF.type, OWL.DatatypeProperty))
g.add((EX.trainabilityValue, RDFS.domain, EX.DogBreed))
g.add((EX.trainabilityValue, RDFS.range, XSD.float))

g.add((EX.trainabilityCategory, RDF.type, OWL.DatatypeProperty))
g.add((EX.trainabilityCategory, RDFS.domain, EX.DogBreed))
g.add((EX.trainabilityCategory, RDFS.range, XSD.string))

g.add((EX.demeanorValue, RDF.type, OWL.DatatypeProperty))
g.add((EX.demeanorValue, RDFS.domain, EX.DogBreed))
g.add((EX.demeanorValue, RDFS.range, XSD.float))

g.add((EX.demeanorCategory, RDF.type, OWL.DatatypeProperty))
g.add((EX.demeanorCategory, RDFS.domain, EX.DogBreed))
g.add((EX.demeanorCategory, RDFS.range, XSD.string))

g.add((EX.biomarkerID, RDF.type, OWL.DatatypeProperty))
g.add((EX.biomarkerID, RDFS.domain, EX.Biomarker))
g.add((EX.biomarkerID, RDFS.range, XSD.string))

g.add((EX.biomarkerName, RDF.type, OWL.DatatypeProperty))
g.add((EX.biomarkerName, RDFS.domain, EX.Biomarker))
g.add((EX.biomarkerName, RDFS.range, XSD.string))

g.add((EX.biomarkerType, RDF.type, OWL.DatatypeProperty))
g.add((EX.biomarkerType, RDFS.domain, EX.Biomarker))
g.add((EX.biomarkerType, RDFS.range, XSD.string))

g.add((EX.diseaseName, RDF.type, OWL.DatatypeProperty))
g.add((EX.diseaseName, RDFS.domain, EX.Disease))
g.add((EX.diseaseName, RDFS.range, XSD.string))

g.add((EX.sex, RDF.type, OWL.DatatypeProperty))
g.add((EX.sex, RDFS.domain, EX.DogIndividual))
g.add((EX.sex, RDFS.range, XSD.string))

g.add((EX.age, RDF.type, OWL.DatatypeProperty))
g.add((EX.age, RDFS.domain, EX.DogIndividual))
g.add((EX.age, RDFS.range, XSD.float))

g.add((EX.weight, RDF.type, OWL.DatatypeProperty))
g.add((EX.weight, RDFS.domain, EX.DogIndividual))
g.add((EX.weight, RDFS.range, XSD.float))

g.add((EX.organism, RDF.type, OWL.DatatypeProperty))
g.add((EX.organism, RDFS.domain, EX.DogIndividual))
g.add((EX.organism, RDFS.range, XSD.string))

g.add((EX.conclusion, RDF.type, OWL.DatatypeProperty))
g.add((EX.conclusion, RDFS.domain, EX.DogIndividual))
g.add((EX.conclusion, RDFS.range, XSD.string))

# Serialize the ontology to Turtle format
ontology_ttl = g.serialize(format='turtle')
print(ontology_ttl)

# Optionally save to a file
with open("dog_breed_ontology.ttl", "w") as f:
    f.write(ontology_ttl)
# Out:
# @prefix ex: <http://example.org/dogbreed#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ex:age a owl:DatatypeProperty ;
#     rdfs:domain ex:DogIndividual ;
#     rdfs:range xsd:float .
#
# ex:associatedWithDisease a owl:ObjectProperty ;
#     rdfs:domain ex:Biomarker ;
#     rdfs:range ex:Disease .
#
# ex:belongsToGroup a owl:ObjectProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range ex:BreedGroup .
#
# ex:biomarkerID a owl:DatatypeProperty ;
#     rdfs:domain ex:Biomarker ;
#     rdfs:range xsd:string .
#
# ex:biomarkerName a owl:DatatypeProperty ;
#     rdfs:domain ex:Biomarker ;
#     rdfs:range xsd:string .
#
# ex:biomarkerType a owl:DatatypeProperty ;
#     rdfs:domain ex:Biomarker ;
#     rdfs:range xsd:string .
#
# ex:breedName a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:string .
#
# ex:conclusion a owl:DatatypeProperty ;
#     rdfs:domain ex:DogIndividual ;
#     rdfs:range xsd:string .
#
# ex:demeanorCategory a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:string .
#
# ex:demeanorValue a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:description a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:string .
#
# ex:diseaseName a owl:DatatypeProperty ;
#     rdfs:domain ex:Disease ;
#     rdfs:range xsd:string .
#
# ex:energyLevelCategory a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:string .
#
# ex:energyLevelValue a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:groomingFrequencyCategory a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:string .
#
# ex:groomingFrequencyValue a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:hasBiomarker a owl:ObjectProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range ex:Biomarker .
#
# ex:hasTemperament a owl:ObjectProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range ex:Temperament .
#
# ex:instanceOfBreed a owl:ObjectProperty ;
#     rdfs:domain ex:DogIndividual ;
#     rdfs:range ex:DogBreed .
#
# ex:maxExpectancy a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:maxHeight a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:maxWeight a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:minExpectancy a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:minHeight a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:minWeight a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:organism a owl:DatatypeProperty ;
#     rdfs:domain ex:DogIndividual ;
#     rdfs:range xsd:string .
#
# ex:popularity a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:integer .
#
# ex:sex a owl:DatatypeProperty ;
#     rdfs:domain ex:DogIndividual ;
#     rdfs:range xsd:string .
#
# ex:sheddingCategory a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:string .
#
# ex:sheddingValue a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:trainabilityCategory a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:string .
#
# ex:trainabilityValue a owl:DatatypeProperty ;
#     rdfs:domain ex:DogBreed ;
#     rdfs:range xsd:float .
#
# ex:weight a owl:DatatypeProperty ;
#     rdfs:domain ex:DogIndividual ;
#     rdfs:range xsd:float .
#
# ex:BreedGroup a owl:Class .
#
# ex:Temperament a owl:Class .
#
# ex:Disease a owl:Class .
#
# ex:Biomarker a owl:Class .
#
# ex:DogIndividual a owl:Class .
#
# ex:DogBreed a owl:Class .

# %%
import pandas as pd
from rdflib import Graph, Namespace, RDF, RDFS, OWL, XSD, URIRef, Literal
from urllib.parse import quote



# Load your CSV file
df = pd.read_csv('dogs_dataset.csv')

# Function to populate the Knowledge Graph with URL encoding
def populate_kg(df, graph):
    for index, row in df.iterrows():
        try:
            # Create URL-encoded URIs (handling potential NaN values)
            breed_name = quote(str(row['breed_name']).replace(' ', '_')) if pd.notna(row['breed_name']) else f"breed_{index}"
            biomarker_id = quote(str(row['biomarkerID'])) if pd.notna(row['biomarkerID']) else f"biomarker_{index}"
            disease_name = quote(str(row['curated_disease_name']).replace(' ', '_')) if pd.notna(row['curated_disease_name']) else f"disease_{index}"
            
            # Debug all relevant fields
            print(f"Row {index} - breed_name: {breed_name}")
            print(f"Row {index} - biomarker_id: {biomarker_id}")
            print(f"Row {index} - disease_name: {disease_name}")
            print(f"Row {index} - biomarkerType: {row['biomarkerType'] if pd.notna(row['biomarkerType']) else 'None'}")

            breed_uri = URIRef(EX[breed_name])
            biomarker_uri = URIRef(EX[biomarker_id])
            disease_uri = URIRef(EX[disease_name])
            dog_uri = URIRef(EX[f"dog_{index}"])
            
            # Add DogBreed instance and properties
            graph.add((breed_uri, RDF.type, EX.DogBreed))
            if pd.notna(row['breed_name']):
                graph.add((breed_uri, EX.breedName, Literal(row['breed_name'], datatype=XSD.string)))
            if pd.notna(row['description']):
                graph.add((breed_uri, EX.description, Literal(row['description'], datatype=XSD.string)))
            # [Add other breed properties as needed]

            # Add Biomarker instance and properties
            graph.add((biomarker_uri, RDF.type, EX.Biomarker))
            if pd.notna(row['biomarkerID']):
                graph.add((biomarker_uri, EX.biomarkerID, Literal(row['biomarkerID'], datatype=XSD.string)))
            if pd.notna(row['biomarkerName']):
                graph.add((biomarker_uri, EX.biomarkerName, Literal(row['biomarkerName'], datatype=XSD.string)))
            if pd.notna(row['biomarkerType']):
                # Use the raw value as a Literal, no URI encoding needed here
                graph.add((biomarker_uri, EX.biomarkerType, Literal(row['biomarkerType'], datatype=XSD.string)))

            # Add Disease instance and properties
            graph.add((disease_uri, RDF.type, EX.Disease))
            if pd.notna(row['curated_disease_name']):
                graph.add((disease_uri, EX.diseaseName, Literal(row['curated_disease_name'], datatype=XSD.string)))

            # Add DogIndividual instance and properties
            graph.add((dog_uri, RDF.type, EX.DogIndividual))
            if pd.notna(row['sex']):
                graph.add((dog_uri, EX.sex, Literal(row['sex'], datatype=XSD.string)))
            # [Add other individual dog properties as needed]

            # Add relationships
            graph.add((breed_uri, EX.hasBiomarker, biomarker_uri))
            graph.add((biomarker_uri, EX.associatedWithDisease, disease_uri))
            graph.add((dog_uri, EX.instanceOfBreed, breed_uri))

        except Exception as e:
            print(f"Error processing row {index}: {str(e)}")
            continue

# Populate the Knowledge Graph
populate_kg(df, g)

# Serialize to Turtle format
try:
    kg_ttl = g.serialize(format='turtle')
    # Save to file
    with open("dog_breed_kg.ttl", "w") as f:
        f.write(kg_ttl)
    print(f"Knowledge Graph created with {len(df)} entries and saved to 'dog_breed_kg.ttl'")
except Exception as e:
    print(f"Serialization error: {str(e)}")
# Out:
# Row 0 - breed_name: Affenpinscher
# Row 0 - biomarker_id: biomarker_0
# Row 0 - disease_name: disease_0
# Row 0 - biomarkerType: None
# Row 1 - breed_name: Afghan_Hound
# Row 1 - biomarker_id: biomarker_1
# Row 1 - disease_name: disease_1
# Row 1 - biomarkerType: None
# Row 2 - breed_name: Airedale_Terrier
# Row 2 - biomarker_id: 1020.0
# Row 2 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 2 - biomarkerType: miRNA
# Row 3 - breed_name: Airedale_Terrier
# Row 3 - biomarker_id: 1021.0
# Row 3 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 3 - biomarkerType: miRNA
# Row 4 - breed_name: Airedale_Terrier
# Row 4 - biomarker_id: 1022.0
# Row 4 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 4 - biomarkerType: miRNA
# Row 5 - breed_name: Airedale_Terrier
# Row 5 - biomarker_id: 1023.0
# Row 5 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 5 - biomarkerType: miRNA
# Row 6 - breed_name: Airedale_Terrier
# Row 6 - biomarker_id: 1024.0
# Row 6 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 6 - biomarkerType: miRNA
# Row 7 - breed_name: Airedale_Terrier
# Row 7 - biomarker_id: 1025.0
# Row 7 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 7 - biomarkerType: miRNA
# Row 8 - breed_name: Airedale_Terrier
# Row 8 - biomarker_id: 2265.0
# Row 8 - disease_name: hemolytic_anemia
# Row 8 - biomarkerType: protein
# Row 9 - breed_name: Akita
# Row 9 - biomarker_id: 2247.0
# Row 9 - disease_name: gastric_neoplasm
# Row 9 - biomarkerType: protein
# Row 10 - breed_name: Akita
# Row 10 - biomarker_id: 1062.0
# Row 10 - disease_name: osteosarcoma
# Row 10 - biomarkerType: miRNA
# Row 11 - breed_name: Akita
# Row 11 - biomarker_id: 1063.0
# Row 11 - disease_name: osteosarcoma
# Row 11 - biomarkerType: miRNA
# Row 12 - breed_name: Akita
# Row 12 - biomarker_id: 2393.0
# Row 12 - disease_name: renal_cell_carcinoma
# Row 12 - biomarkerType: protein
# Row 13 - breed_name: Alaskan_Malamute
# Row 13 - biomarker_id: 184.0
# Row 13 - disease_name: hepatocellular_carcinoma
# Row 13 - biomarkerType: gene
# Row 14 - breed_name: Alaskan_Malamute
# Row 14 - biomarker_id: 2199.0
# Row 14 - disease_name: neoplasm
# Row 14 - biomarkerType: protein
# Row 15 - breed_name: Alaskan_Malamute
# Row 15 - biomarker_id: 2247.0
# Row 15 - disease_name: gastric_neoplasm
# Row 15 - biomarkerType: protein
# Row 16 - breed_name: Alaskan_Malamute
# Row 16 - biomarker_id: 2374.0
# Row 16 - disease_name: osteosarcoma
# Row 16 - biomarkerType: protein
# Row 17 - breed_name: American_Bulldog
# Row 17 - biomarker_id: 727.0
# Row 17 - disease_name: central_nervous_system_disorder
# Row 17 - biomarkerType: metabolite
# Row 18 - breed_name: American_Bulldog
# Row 18 - biomarker_id: 2260.0
# Row 18 - disease_name: intestinal_disorder
# Row 18 - biomarkerType: protein
# Row 19 - breed_name: American_Bulldog
# Row 19 - biomarker_id: 683.0
# Row 19 - disease_name: central_nervous_system_disorder
# Row 19 - biomarkerType: metabolite
# Row 20 - breed_name: American_Bulldog
# Row 20 - biomarker_id: 2336.0
# Row 20 - disease_name: neoplasm
# Row 20 - biomarkerType: protein
# Row 21 - breed_name: American_English_Coonhound
# Row 21 - biomarker_id: biomarker_21
# Row 21 - disease_name: disease_21
# Row 21 - biomarkerType: None
# Row 22 - breed_name: American_Eskimo_Dog
# Row 22 - biomarker_id: 727.0
# Row 22 - disease_name: central_nervous_system_disorder
# Row 22 - biomarkerType: metabolite
# Row 23 - breed_name: American_Eskimo_Dog
# Row 23 - biomarker_id: 683.0
# Row 23 - disease_name: central_nervous_system_disorder
# Row 23 - biomarkerType: metabolite
# Row 24 - breed_name: American_Foxhound
# Row 24 - biomarker_id: biomarker_24
# Row 24 - disease_name: disease_24
# Row 24 - biomarkerType: None
# Row 25 - breed_name: American_Hairless_Terrier
# Row 25 - biomarker_id: biomarker_25
# Row 25 - disease_name: disease_25
# Row 25 - biomarkerType: None
# Row 26 - breed_name: American_Leopard_Hound
# Row 26 - biomarker_id: biomarker_26
# Row 26 - disease_name: disease_26
# Row 26 - biomarkerType: None
# Row 27 - breed_name: American_Staffordshire_Terrier
# Row 27 - biomarker_id: 2336.0
# Row 27 - disease_name: neoplasm
# Row 27 - biomarkerType: protein
# Row 28 - breed_name: American_Staffordshire_Terrier
# Row 28 - biomarker_id: 2374.0
# Row 28 - disease_name: osteosarcoma
# Row 28 - biomarkerType: protein
# Row 29 - breed_name: American_Staffordshire_Terrier
# Row 29 - biomarker_id: 1062.0
# Row 29 - disease_name: osteosarcoma
# Row 29 - biomarkerType: miRNA
# Row 30 - breed_name: American_Staffordshire_Terrier
# Row 30 - biomarker_id: 1063.0
# Row 30 - disease_name: osteosarcoma
# Row 30 - biomarkerType: miRNA
# Row 31 - breed_name: American_Staffordshire_Terrier
# Row 31 - biomarker_id: 2391.0
# Row 31 - disease_name: osteoarthritis
# Row 31 - biomarkerType: protein
# Row 32 - breed_name: American_Water_Spaniel
# Row 32 - biomarker_id: biomarker_32
# Row 32 - disease_name: disease_32
# Row 32 - biomarkerType: None
# Row 33 - breed_name: Anatolian_Shepherd_Dog
# Row 33 - biomarker_id: 1859.0
# Row 33 - disease_name: Parvoviridae_infectious_disease
# Row 33 - biomarkerType: other
# Row 34 - breed_name: Anatolian_Shepherd_Dog
# Row 34 - biomarker_id: 2205.0
# Row 34 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 34 - biomarkerType: protein
# Row 35 - breed_name: Anatolian_Shepherd_Dog
# Row 35 - biomarker_id: 2207.0
# Row 35 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 35 - biomarkerType: protein
# Row 36 - breed_name: Anatolian_Shepherd_Dog
# Row 36 - biomarker_id: 2208.0
# Row 36 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 36 - biomarkerType: protein
# Row 37 - breed_name: Anatolian_Shepherd_Dog
# Row 37 - biomarker_id: 2209.0
# Row 37 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 37 - biomarkerType: protein
# Row 38 - breed_name: Anatolian_Shepherd_Dog
# Row 38 - biomarker_id: 2210.0
# Row 38 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 38 - biomarkerType: protein
# Row 39 - breed_name: Anatolian_Shepherd_Dog
# Row 39 - biomarker_id: 2211.0
# Row 39 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 39 - biomarkerType: protein
# Row 40 - breed_name: Anatolian_Shepherd_Dog
# Row 40 - biomarker_id: 2212.0
# Row 40 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 40 - biomarkerType: protein
# Row 41 - breed_name: Anatolian_Shepherd_Dog
# Row 41 - biomarker_id: 2213.0
# Row 41 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 41 - biomarkerType: protein
# Row 42 - breed_name: Anatolian_Shepherd_Dog
# Row 42 - biomarker_id: 2214.0
# Row 42 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 42 - biomarkerType: protein
# Row 43 - breed_name: Anatolian_Shepherd_Dog
# Row 43 - biomarker_id: 2215.0
# Row 43 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 43 - biomarkerType: protein
# Row 44 - breed_name: Anatolian_Shepherd_Dog
# Row 44 - biomarker_id: 2216.0
# Row 44 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 44 - biomarkerType: protein
# Row 45 - breed_name: Anatolian_Shepherd_Dog
# Row 45 - biomarker_id: 2217.0
# Row 45 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 45 - biomarkerType: protein
# Row 46 - breed_name: Anatolian_Shepherd_Dog
# Row 46 - biomarker_id: 2218.0
# Row 46 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 46 - biomarkerType: protein
# Row 47 - breed_name: Anatolian_Shepherd_Dog
# Row 47 - biomarker_id: 2219.0
# Row 47 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 47 - biomarkerType: protein
# Row 48 - breed_name: Anatolian_Shepherd_Dog
# Row 48 - biomarker_id: 2220.0
# Row 48 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 48 - biomarkerType: protein
# Row 49 - breed_name: Anatolian_Shepherd_Dog
# Row 49 - biomarker_id: 2221.0
# Row 49 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 49 - biomarkerType: protein
# Row 50 - breed_name: Anatolian_Shepherd_Dog
# Row 50 - biomarker_id: 2222.0
# Row 50 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 50 - biomarkerType: protein
# Row 51 - breed_name: Anatolian_Shepherd_Dog
# Row 51 - biomarker_id: 2223.0
# Row 51 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 51 - biomarkerType: protein
# Row 52 - breed_name: Anatolian_Shepherd_Dog
# Row 52 - biomarker_id: 2224.0
# Row 52 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 52 - biomarkerType: protein
# Row 53 - breed_name: Anatolian_Shepherd_Dog
# Row 53 - biomarker_id: 2208.0
# Row 53 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 53 - biomarkerType: protein
# Row 54 - breed_name: Anatolian_Shepherd_Dog
# Row 54 - biomarker_id: 2205.0
# Row 54 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 54 - biomarkerType: protein
# Row 55 - breed_name: Anatolian_Shepherd_Dog
# Row 55 - biomarker_id: 2226.0
# Row 55 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 55 - biomarkerType: protein
# Row 56 - breed_name: Anatolian_Shepherd_Dog
# Row 56 - biomarker_id: 2227.0
# Row 56 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 56 - biomarkerType: protein
# Row 57 - breed_name: Anatolian_Shepherd_Dog
# Row 57 - biomarker_id: 2228.0
# Row 57 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 57 - biomarkerType: protein
# Row 58 - breed_name: Anatolian_Shepherd_Dog
# Row 58 - biomarker_id: 2229.0
# Row 58 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 58 - biomarkerType: protein
# Row 59 - breed_name: Anatolian_Shepherd_Dog
# Row 59 - biomarker_id: 2230.0
# Row 59 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 59 - biomarkerType: protein
# Row 60 - breed_name: Anatolian_Shepherd_Dog
# Row 60 - biomarker_id: 2231.0
# Row 60 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 60 - biomarkerType: protein
# Row 61 - breed_name: Anatolian_Shepherd_Dog
# Row 61 - biomarker_id: 2232.0
# Row 61 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 61 - biomarkerType: protein
# Row 62 - breed_name: Anatolian_Shepherd_Dog
# Row 62 - biomarker_id: 2233.0
# Row 62 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 62 - biomarkerType: protein
# Row 63 - breed_name: Anatolian_Shepherd_Dog
# Row 63 - biomarker_id: 2224.0
# Row 63 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 63 - biomarkerType: protein
# Row 64 - breed_name: Anatolian_Shepherd_Dog
# Row 64 - biomarker_id: 2236.0
# Row 64 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 64 - biomarkerType: protein
# Row 65 - breed_name: Anatolian_Shepherd_Dog
# Row 65 - biomarker_id: 2205.0
# Row 65 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 65 - biomarkerType: protein
# Row 66 - breed_name: Anatolian_Shepherd_Dog
# Row 66 - biomarker_id: 2237.0
# Row 66 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 66 - biomarkerType: protein
# Row 67 - breed_name: Anatolian_Shepherd_Dog
# Row 67 - biomarker_id: 1062.0
# Row 67 - disease_name: osteosarcoma
# Row 67 - biomarkerType: miRNA
# Row 68 - breed_name: Anatolian_Shepherd_Dog
# Row 68 - biomarker_id: 1063.0
# Row 68 - disease_name: osteosarcoma
# Row 68 - biomarkerType: miRNA
# Row 69 - breed_name: Appenzeller_Sennenhund
# Row 69 - biomarker_id: biomarker_69
# Row 69 - disease_name: disease_69
# Row 69 - biomarkerType: None
# Row 70 - breed_name: Australian_Cattle_Dog
# Row 70 - biomarker_id: 2374.0
# Row 70 - disease_name: osteosarcoma
# Row 70 - biomarkerType: protein
# Row 71 - breed_name: Australian_Kelpie
# Row 71 - biomarker_id: biomarker_71
# Row 71 - disease_name: disease_71
# Row 71 - biomarkerType: None
# Row 72 - breed_name: Australian_Shepherd
# Row 72 - biomarker_id: 2199.0
# Row 72 - disease_name: neoplasm
# Row 72 - biomarkerType: protein
# Row 73 - breed_name: Australian_Shepherd
# Row 73 - biomarker_id: 2265.0
# Row 73 - disease_name: hemolytic_anemia
# Row 73 - biomarkerType: protein
# Row 74 - breed_name: Australian_Shepherd
# Row 74 - biomarker_id: 2266.0
# Row 74 - disease_name: diabetes_mellitus
# Row 74 - biomarkerType: metabolite
# Row 75 - breed_name: Australian_Shepherd
# Row 75 - biomarker_id: 684.0
# Row 75 - disease_name: diabetes_mellitus
# Row 75 - biomarkerType: metabolite
# Row 76 - breed_name: Australian_Shepherd
# Row 76 - biomarker_id: 2271.0
# Row 76 - disease_name: diabetes_mellitus
# Row 76 - biomarkerType: protein
# Row 77 - breed_name: Australian_Shepherd
# Row 77 - biomarker_id: 2281.0
# Row 77 - disease_name: diabetes_mellitus
# Row 77 - biomarkerType: protein
# Row 78 - breed_name: Australian_Shepherd
# Row 78 - biomarker_id: 2293.0
# Row 78 - disease_name: diabetes_mellitus
# Row 78 - biomarkerType: protein
# Row 79 - breed_name: Australian_Shepherd
# Row 79 - biomarker_id: 685.0
# Row 79 - disease_name: diabetes_mellitus
# Row 79 - biomarkerType: metabolite
# Row 80 - breed_name: Australian_Shepherd
# Row 80 - biomarker_id: 2311.0
# Row 80 - disease_name: diabetes_mellitus
# Row 80 - biomarkerType: protein
# Row 81 - breed_name: Australian_Shepherd
# Row 81 - biomarker_id: 2320.0
# Row 81 - disease_name: diabetes_mellitus
# Row 81 - biomarkerType: protein
# Row 82 - breed_name: Australian_Shepherd
# Row 82 - biomarker_id: 2331.0
# Row 82 - disease_name: diabetes_mellitus
# Row 82 - biomarkerType: metabolite
# Row 83 - breed_name: Australian_Shepherd
# Row 83 - biomarker_id: 2341.0
# Row 83 - disease_name: diabetes_mellitus
# Row 83 - biomarkerType: protein
# Row 84 - breed_name: Australian_Shepherd
# Row 84 - biomarker_id: 654.0
# Row 84 - disease_name: diabetes_mellitus
# Row 84 - biomarkerType: protein
# Row 85 - breed_name: Australian_Shepherd
# Row 85 - biomarker_id: 2362.0
# Row 85 - disease_name: diabetes_mellitus
# Row 85 - biomarkerType: metabolite
# Row 86 - breed_name: Australian_Shepherd
# Row 86 - biomarker_id: 2371.0
# Row 86 - disease_name: diabetes_mellitus
# Row 86 - biomarkerType: metabolite
# Row 87 - breed_name: Australian_Shepherd
# Row 87 - biomarker_id: 2373.0
# Row 87 - disease_name: diabetes_mellitus
# Row 87 - biomarkerType: metabolite
# Row 88 - breed_name: Australian_Stumpy_Tail_Cattle_Dog
# Row 88 - biomarker_id: biomarker_88
# Row 88 - disease_name: disease_88
# Row 88 - biomarkerType: None
# Row 89 - breed_name: Australian_Terrier
# Row 89 - biomarker_id: biomarker_89
# Row 89 - disease_name: disease_89
# Row 89 - biomarkerType: None
# Row 90 - breed_name: Azawakh
# Row 90 - biomarker_id: biomarker_90
# Row 90 - disease_name: disease_90
# Row 90 - biomarkerType: None
# Row 91 - breed_name: Barbet
# Row 91 - biomarker_id: biomarker_91
# Row 91 - disease_name: disease_91
# Row 91 - biomarkerType: None
# Row 92 - breed_name: Basenji
# Row 92 - biomarker_id: biomarker_92
# Row 92 - disease_name: disease_92
# Row 92 - biomarkerType: None
# Row 93 - breed_name: Basset_Fauve_de_Bretagne
# Row 93 - biomarker_id: biomarker_93
# Row 93 - disease_name: disease_93
# Row 93 - biomarkerType: None
# Row 94 - breed_name: Basset_Hound
# Row 94 - biomarker_id: 2436.0
# Row 94 - disease_name: squamous_cell_carcinoma
# Row 94 - biomarkerType: protein
# Row 95 - breed_name: Basset_Hound
# Row 95 - biomarker_id: 2247.0
# Row 95 - disease_name: gastric_neoplasm
# Row 95 - biomarkerType: protein
# Row 96 - breed_name: Bavarian_Mountain_Scent_Hound
# Row 96 - biomarker_id: biomarker_96
# Row 96 - disease_name: disease_96
# Row 96 - biomarkerType: None
# Row 97 - breed_name: Beagle
# Row 97 - biomarker_id: biomarker_97
# Row 97 - disease_name: disease_97
# Row 97 - biomarkerType: None
# Row 98 - breed_name: Bearded_Collie
# Row 98 - biomarker_id: 2442.0
# Row 98 - disease_name: meningioma
# Row 98 - biomarkerType: protein
# Row 99 - breed_name: Beauceron
# Row 99 - biomarker_id: biomarker_99
# Row 99 - disease_name: disease_99
# Row 99 - biomarkerType: None
# Row 100 - breed_name: Bedlington_Terrier
# Row 100 - biomarker_id: 2456.0
# Row 100 - disease_name: chronic_kidney_disease
# Row 100 - biomarkerType: protein
# Row 101 - breed_name: Bedlington_Terrier
# Row 101 - biomarker_id: 2388.0
# Row 101 - disease_name: hepatitis
# Row 101 - biomarkerType: protein
# Row 102 - breed_name: Belgian_Laekenois
# Row 102 - biomarker_id: biomarker_102
# Row 102 - disease_name: disease_102
# Row 102 - biomarkerType: None
# Row 103 - breed_name: Belgian_Malinois
# Row 103 - biomarker_id: biomarker_103
# Row 103 - disease_name: disease_103
# Row 103 - biomarkerType: None
# Row 104 - breed_name: Belgian_Sheepdog
# Row 104 - biomarker_id: biomarker_104
# Row 104 - disease_name: disease_104
# Row 104 - biomarkerType: None
# Row 105 - breed_name: Belgian_Tervuren
# Row 105 - biomarker_id: 2442.0
# Row 105 - disease_name: meningioma
# Row 105 - biomarkerType: protein
# Row 106 - breed_name: Bergamasco_Sheepdog
# Row 106 - biomarker_id: biomarker_106
# Row 106 - disease_name: disease_106
# Row 106 - biomarkerType: None
# Row 107 - breed_name: Berger_Picard
# Row 107 - biomarker_id: biomarker_107
# Row 107 - disease_name: disease_107
# Row 107 - biomarkerType: None
# Row 108 - breed_name: Bernese_Mountain_Dog
# Row 108 - biomarker_id: 727.0
# Row 108 - disease_name: central_nervous_system_disorder
# Row 108 - biomarkerType: metabolite
# Row 109 - breed_name: Bernese_Mountain_Dog
# Row 109 - biomarker_id: 2176.0
# Row 109 - disease_name: lung_adenocarcinoma
# Row 109 - biomarkerType: protein
# Row 110 - breed_name: Bernese_Mountain_Dog
# Row 110 - biomarker_id: 2199.0
# Row 110 - disease_name: neoplasm
# Row 110 - biomarkerType: protein
# Row 111 - breed_name: Bernese_Mountain_Dog
# Row 111 - biomarker_id: 1863.0
# Row 111 - disease_name: neoplasm
# Row 111 - biomarkerType: other
# Row 112 - breed_name: Bernese_Mountain_Dog
# Row 112 - biomarker_id: 683.0
# Row 112 - disease_name: central_nervous_system_disorder
# Row 112 - biomarkerType: metabolite
# Row 113 - breed_name: Bernese_Mountain_Dog
# Row 113 - biomarker_id: 687.0
# Row 113 - disease_name: intestinal_disorder
# Row 113 - biomarkerType: metabolite
# Row 114 - breed_name: Bernese_Mountain_Dog
# Row 114 - biomarker_id: 688.0
# Row 114 - disease_name: intestinal_disorder
# Row 114 - biomarkerType: metabolite
# Row 115 - breed_name: Bernese_Mountain_Dog
# Row 115 - biomarker_id: 689.0
# Row 115 - disease_name: intestinal_disorder
# Row 115 - biomarkerType: metabolite
# Row 116 - breed_name: Bernese_Mountain_Dog
# Row 116 - biomarker_id: 690.0
# Row 116 - disease_name: intestinal_disorder
# Row 116 - biomarkerType: metabolite
# Row 117 - breed_name: Bernese_Mountain_Dog
# Row 117 - biomarker_id: 1062.0
# Row 117 - disease_name: osteosarcoma
# Row 117 - biomarkerType: miRNA
# Row 118 - breed_name: Bernese_Mountain_Dog
# Row 118 - biomarker_id: 1063.0
# Row 118 - disease_name: osteosarcoma
# Row 118 - biomarkerType: miRNA
# Row 119 - breed_name: Bernese_Mountain_Dog
# Row 119 - biomarker_id: 1065.0
# Row 119 - disease_name: melanoma
# Row 119 - biomarkerType: miRNA
# Row 120 - breed_name: Bernese_Mountain_Dog
# Row 120 - biomarker_id: 1018.0
# Row 120 - disease_name: melanoma
# Row 120 - biomarkerType: miRNA
# Row 121 - breed_name: Bernese_Mountain_Dog
# Row 121 - biomarker_id: 1066.0
# Row 121 - disease_name: melanoma
# Row 121 - biomarkerType: miRNA
# Row 122 - breed_name: Bernese_Mountain_Dog
# Row 122 - biomarker_id: 1067.0
# Row 122 - disease_name: melanoma
# Row 122 - biomarkerType: miRNA
# Row 123 - breed_name: Bernese_Mountain_Dog
# Row 123 - biomarker_id: 1068.0
# Row 123 - disease_name: melanoma
# Row 123 - biomarkerType: miRNA
# Row 124 - breed_name: Bernese_Mountain_Dog
# Row 124 - biomarker_id: 1069.0
# Row 124 - disease_name: melanoma
# Row 124 - biomarkerType: miRNA
# Row 125 - breed_name: Bernese_Mountain_Dog
# Row 125 - biomarker_id: 1070.0
# Row 125 - disease_name: melanoma
# Row 125 - biomarkerType: miRNA
# Row 126 - breed_name: Bernese_Mountain_Dog
# Row 126 - biomarker_id: 1071.0
# Row 126 - disease_name: melanoma
# Row 126 - biomarkerType: miRNA
# Row 127 - breed_name: Bernese_Mountain_Dog
# Row 127 - biomarker_id: 1072.0
# Row 127 - disease_name: melanoma
# Row 127 - biomarkerType: miRNA
# Row 128 - breed_name: Bernese_Mountain_Dog
# Row 128 - biomarker_id: 1073.0
# Row 128 - disease_name: melanoma
# Row 128 - biomarkerType: miRNA
# Row 129 - breed_name: Bernese_Mountain_Dog
# Row 129 - biomarker_id: 1074.0
# Row 129 - disease_name: melanoma
# Row 129 - biomarkerType: miRNA
# Row 130 - breed_name: Bernese_Mountain_Dog
# Row 130 - biomarker_id: 1075.0
# Row 130 - disease_name: melanoma
# Row 130 - biomarkerType: miRNA
# Row 131 - breed_name: Bernese_Mountain_Dog
# Row 131 - biomarker_id: 1076.0
# Row 131 - disease_name: melanoma
# Row 131 - biomarkerType: miRNA
# Row 132 - breed_name: Bernese_Mountain_Dog
# Row 132 - biomarker_id: 1077.0
# Row 132 - disease_name: melanoma
# Row 132 - biomarkerType: miRNA
# Row 133 - breed_name: Bernese_Mountain_Dog
# Row 133 - biomarker_id: 2403.0
# Row 133 - disease_name: kidney_disorder
# Row 133 - biomarkerType: protein
# Row 134 - breed_name: Bichon_Frise
# Row 134 - biomarker_id: 2409.0
# Row 134 - disease_name: intestinal_disorder
# Row 134 - biomarkerType: protein
# Row 135 - breed_name: Bichon_Frise
# Row 135 - biomarker_id: 2410.0
# Row 135 - disease_name: intestinal_disorder
# Row 135 - biomarkerType: protein
# Row 136 - breed_name: Bichon_Frise
# Row 136 - biomarker_id: 2411.0
# Row 136 - disease_name: intestinal_disorder
# Row 136 - biomarkerType: protein
# Row 137 - breed_name: Bichon_Frise
# Row 137 - biomarker_id: 2413.0
# Row 137 - disease_name: intestinal_disorder
# Row 137 - biomarkerType: protein
# Row 138 - breed_name: Bichon_Frise
# Row 138 - biomarker_id: 2418.0
# Row 138 - disease_name: meningoencephalitis
# Row 138 - biomarkerType: protein
# Row 139 - breed_name: Bichon_Frise
# Row 139 - biomarker_id: 2419.0
# Row 139 - disease_name: intestinal_disorder
# Row 139 - biomarkerType: protein
# Row 140 - breed_name: Bichon_Frise
# Row 140 - biomarker_id: 2423.0
# Row 140 - disease_name: intestinal_disorder
# Row 140 - biomarkerType: protein
# Row 141 - breed_name: Bichon_Frise
# Row 141 - biomarker_id: 2426.0
# Row 141 - disease_name: intestinal_disorder
# Row 141 - biomarkerType: protein
# Row 142 - breed_name: Bichon_Frise
# Row 142 - biomarker_id: 2433.0
# Row 142 - disease_name: intestinal_disorder
# Row 142 - biomarkerType: protein
# Row 143 - breed_name: Bichon_Frise
# Row 143 - biomarker_id: 2443.0
# Row 143 - disease_name: intestinal_disorder
# Row 143 - biomarkerType: protein
# Row 144 - breed_name: Bichon_Frise
# Row 144 - biomarker_id: 2448.0
# Row 144 - disease_name: patent_ductus_arteriosus
# Row 144 - biomarkerType: protein
# Row 145 - breed_name: Bichon_Frise
# Row 145 - biomarker_id: 2453.0
# Row 145 - disease_name: intestinal_disorder
# Row 145 - biomarkerType: protein
# Row 146 - breed_name: Bichon_Frise
# Row 146 - biomarker_id: 2455.0
# Row 146 - disease_name: intestinal_disorder
# Row 146 - biomarkerType: protein
# Row 147 - breed_name: Bichon_Frise
# Row 147 - biomarker_id: 2456.0
# Row 147 - disease_name: chronic_kidney_disease
# Row 147 - biomarkerType: protein
# Row 148 - breed_name: Bichon_Frise
# Row 148 - biomarker_id: 2460.0
# Row 148 - disease_name: intestinal_disorder
# Row 148 - biomarkerType: protein
# Row 149 - breed_name: Bichon_Frise
# Row 149 - biomarker_id: 2461.0
# Row 149 - disease_name: intestinal_disorder
# Row 149 - biomarkerType: protein
# Row 150 - breed_name: Bichon_Frise
# Row 150 - biomarker_id: 2167.0
# Row 150 - disease_name: intestinal_disorder
# Row 150 - biomarkerType: protein
# Row 151 - breed_name: Bichon_Frise
# Row 151 - biomarker_id: 2168.0
# Row 151 - disease_name: intestinal_disorder
# Row 151 - biomarkerType: protein
# Row 152 - breed_name: Bichon_Frise
# Row 152 - biomarker_id: 2170.0
# Row 152 - disease_name: intestinal_disorder
# Row 152 - biomarkerType: protein
# Row 153 - breed_name: Bichon_Frise
# Row 153 - biomarker_id: 185.0
# Row 153 - disease_name: breast_neoplasm
# Row 153 - biomarkerType: gene
# Row 154 - breed_name: Bichon_Frise
# Row 154 - biomarker_id: 2179.0
# Row 154 - disease_name: intestinal_disorder
# Row 154 - biomarkerType: protein
# Row 155 - breed_name: Bichon_Frise
# Row 155 - biomarker_id: 2189.0
# Row 155 - disease_name: intestinal_disorder
# Row 155 - biomarkerType: protein
# Row 156 - breed_name: Bichon_Frise
# Row 156 - biomarker_id: 2198.0
# Row 156 - disease_name: intestinal_disorder
# Row 156 - biomarkerType: protein
# Row 157 - breed_name: Bichon_Frise
# Row 157 - biomarker_id: 2206.0
# Row 157 - disease_name: intestinal_disorder
# Row 157 - biomarkerType: protein
# Row 158 - breed_name: Bichon_Frise
# Row 158 - biomarker_id: 2429.0
# Row 158 - disease_name: intestinal_disorder
# Row 158 - biomarkerType: protein
# Row 159 - breed_name: Bichon_Frise
# Row 159 - biomarker_id: 2225.0
# Row 159 - disease_name: intestinal_disorder
# Row 159 - biomarkerType: protein
# Row 160 - breed_name: Bichon_Frise
# Row 160 - biomarker_id: 2234.0
# Row 160 - disease_name: intestinal_disorder
# Row 160 - biomarkerType: protein
# Row 161 - breed_name: Bichon_Frise
# Row 161 - biomarker_id: 2235.0
# Row 161 - disease_name: intestinal_disorder
# Row 161 - biomarkerType: protein
# Row 162 - breed_name: Bichon_Frise
# Row 162 - biomarker_id: 2240.0
# Row 162 - disease_name: intestinal_disorder
# Row 162 - biomarkerType: protein
# Row 163 - breed_name: Bichon_Frise
# Row 163 - biomarker_id: 2250.0
# Row 163 - disease_name: intestinal_disorder
# Row 163 - biomarkerType: protein
# Row 164 - breed_name: Bichon_Frise
# Row 164 - biomarker_id: 2266.0
# Row 164 - disease_name: diabetes_mellitus
# Row 164 - biomarkerType: metabolite
# Row 165 - breed_name: Bichon_Frise
# Row 165 - biomarker_id: 684.0
# Row 165 - disease_name: diabetes_mellitus
# Row 165 - biomarkerType: metabolite
# Row 166 - breed_name: Bichon_Frise
# Row 166 - biomarker_id: 2271.0
# Row 166 - disease_name: diabetes_mellitus
# Row 166 - biomarkerType: protein
# Row 167 - breed_name: Bichon_Frise
# Row 167 - biomarker_id: 2281.0
# Row 167 - disease_name: diabetes_mellitus
# Row 167 - biomarkerType: protein
# Row 168 - breed_name: Bichon_Frise
# Row 168 - biomarker_id: 2292.0
# Row 168 - disease_name: intestinal_disorder
# Row 168 - biomarkerType: protein
# Row 169 - breed_name: Bichon_Frise
# Row 169 - biomarker_id: 2293.0
# Row 169 - disease_name: diabetes_mellitus
# Row 169 - biomarkerType: protein
# Row 170 - breed_name: Bichon_Frise
# Row 170 - biomarker_id: 685.0
# Row 170 - disease_name: diabetes_mellitus
# Row 170 - biomarkerType: metabolite
# Row 171 - breed_name: Bichon_Frise
# Row 171 - biomarker_id: 2311.0
# Row 171 - disease_name: diabetes_mellitus
# Row 171 - biomarkerType: protein
# Row 172 - breed_name: Bichon_Frise
# Row 172 - biomarker_id: 2320.0
# Row 172 - disease_name: diabetes_mellitus
# Row 172 - biomarkerType: protein
# Row 173 - breed_name: Bichon_Frise
# Row 173 - biomarker_id: 2331.0
# Row 173 - disease_name: diabetes_mellitus
# Row 173 - biomarkerType: metabolite
# Row 174 - breed_name: Bichon_Frise
# Row 174 - biomarker_id: 2341.0
# Row 174 - disease_name: diabetes_mellitus
# Row 174 - biomarkerType: protein
# Row 175 - breed_name: Bichon_Frise
# Row 175 - biomarker_id: 654.0
# Row 175 - disease_name: diabetes_mellitus
# Row 175 - biomarkerType: protein
# Row 176 - breed_name: Bichon_Frise
# Row 176 - biomarker_id: 2362.0
# Row 176 - disease_name: diabetes_mellitus
# Row 176 - biomarkerType: metabolite
# Row 177 - breed_name: Bichon_Frise
# Row 177 - biomarker_id: 2371.0
# Row 177 - disease_name: diabetes_mellitus
# Row 177 - biomarkerType: metabolite
# Row 178 - breed_name: Bichon_Frise
# Row 178 - biomarker_id: 1048.0
# Row 178 - disease_name: inflammatory_bowel_disease
# Row 178 - biomarkerType: miRNA
# Row 179 - breed_name: Bichon_Frise
# Row 179 - biomarker_id: 1049.0
# Row 179 - disease_name: inflammatory_bowel_disease
# Row 179 - biomarkerType: miRNA
# Row 180 - breed_name: Bichon_Frise
# Row 180 - biomarker_id: 1050.0
# Row 180 - disease_name: inflammatory_bowel_disease
# Row 180 - biomarkerType: miRNA
# Row 181 - breed_name: Bichon_Frise
# Row 181 - biomarker_id: 1051.0
# Row 181 - disease_name: inflammatory_bowel_disease
# Row 181 - biomarkerType: miRNA
# Row 182 - breed_name: Bichon_Frise
# Row 182 - biomarker_id: 2373.0
# Row 182 - disease_name: diabetes_mellitus
# Row 182 - biomarkerType: metabolite
# Row 183 - breed_name: Bichon_Frise
# Row 183 - biomarker_id: 1052.0
# Row 183 - disease_name: inflammatory_bowel_disease
# Row 183 - biomarkerType: miRNA
# Row 184 - breed_name: Bichon_Frise
# Row 184 - biomarker_id: 1053.0
# Row 184 - disease_name: inflammatory_bowel_disease
# Row 184 - biomarkerType: miRNA
# Row 185 - breed_name: Bichon_Frise
# Row 185 - biomarker_id: 1021.0
# Row 185 - disease_name: inflammatory_bowel_disease
# Row 185 - biomarkerType: miRNA
# Row 186 - breed_name: Bichon_Frise
# Row 186 - biomarker_id: 2378.0
# Row 186 - disease_name: intestinal_disorder
# Row 186 - biomarkerType: protein
# Row 187 - breed_name: Bichon_Frise
# Row 187 - biomarker_id: 2386.0
# Row 187 - disease_name: neoplasm
# Row 187 - biomarkerType: protein
# Row 188 - breed_name: Bichon_Frise
# Row 188 - biomarker_id: 2397.0
# Row 188 - disease_name: intestinal_disorder
# Row 188 - biomarkerType: protein
# Row 189 - breed_name: Bichon_Frise
# Row 189 - biomarker_id: 2400.0
# Row 189 - disease_name: intestinal_disorder
# Row 189 - biomarkerType: protein
# Row 190 - breed_name: Bichon_Frise
# Row 190 - biomarker_id: 2405.0
# Row 190 - disease_name: intestinal_disorder
# Row 190 - biomarkerType: protein
# Row 191 - breed_name: Bichon_Frise
# Row 191 - biomarker_id: 2408.0
# Row 191 - disease_name: intestinal_disorder
# Row 191 - biomarkerType: protein
# Row 192 - breed_name: Biewer_Terrier
# Row 192 - biomarker_id: biomarker_192
# Row 192 - disease_name: disease_192
# Row 192 - biomarkerType: None
# Row 193 - breed_name: Black_and_Tan_Coonhound
# Row 193 - biomarker_id: biomarker_193
# Row 193 - disease_name: disease_193
# Row 193 - biomarkerType: None
# Row 194 - breed_name: Black_Russian_Terrier
# Row 194 - biomarker_id: 2336.0
# Row 194 - disease_name: neoplasm
# Row 194 - biomarkerType: protein
# Row 195 - breed_name: Bloodhound
# Row 195 - biomarker_id: 686.0
# Row 195 - disease_name: acute_pancreatitis
# Row 195 - biomarkerType: metabolite
# Row 196 - breed_name: Bluetick_Coonhound
# Row 196 - biomarker_id: biomarker_196
# Row 196 - disease_name: disease_196
# Row 196 - biomarkerType: None
# Row 197 - breed_name: Boerboel
# Row 197 - biomarker_id: biomarker_197
# Row 197 - disease_name: disease_197
# Row 197 - biomarkerType: None
# Row 198 - breed_name: Bohemian_Shepherd
# Row 198 - biomarker_id: biomarker_198
# Row 198 - disease_name: disease_198
# Row 198 - biomarkerType: None
# Row 199 - breed_name: Bolognese
# Row 199 - biomarker_id: 2336.0
# Row 199 - disease_name: neoplasm
# Row 199 - biomarkerType: protein
# Row 200 - breed_name: Bolognese
# Row 200 - biomarker_id: 687.0
# Row 200 - disease_name: intestinal_disorder
# Row 200 - biomarkerType: metabolite
# Row 201 - breed_name: Bolognese
# Row 201 - biomarker_id: 688.0
# Row 201 - disease_name: intestinal_disorder
# Row 201 - biomarkerType: metabolite
# Row 202 - breed_name: Bolognese
# Row 202 - biomarker_id: 689.0
# Row 202 - disease_name: intestinal_disorder
# Row 202 - biomarkerType: metabolite
# Row 203 - breed_name: Bolognese
# Row 203 - biomarker_id: 690.0
# Row 203 - disease_name: intestinal_disorder
# Row 203 - biomarkerType: metabolite
# Row 204 - breed_name: Border_Collie
# Row 204 - biomarker_id: 2409.0
# Row 204 - disease_name: intestinal_disorder
# Row 204 - biomarkerType: protein
# Row 205 - breed_name: Border_Collie
# Row 205 - biomarker_id: 2410.0
# Row 205 - disease_name: intestinal_disorder
# Row 205 - biomarkerType: protein
# Row 206 - breed_name: Border_Collie
# Row 206 - biomarker_id: 2411.0
# Row 206 - disease_name: intestinal_disorder
# Row 206 - biomarkerType: protein
# Row 207 - breed_name: Border_Collie
# Row 207 - biomarker_id: 2413.0
# Row 207 - disease_name: intestinal_disorder
# Row 207 - biomarkerType: protein
# Row 208 - breed_name: Border_Collie
# Row 208 - biomarker_id: 2419.0
# Row 208 - disease_name: intestinal_disorder
# Row 208 - biomarkerType: protein
# Row 209 - breed_name: Border_Collie
# Row 209 - biomarker_id: 2423.0
# Row 209 - disease_name: intestinal_disorder
# Row 209 - biomarkerType: protein
# Row 210 - breed_name: Border_Collie
# Row 210 - biomarker_id: 2426.0
# Row 210 - disease_name: intestinal_disorder
# Row 210 - biomarkerType: protein
# Row 211 - breed_name: Border_Collie
# Row 211 - biomarker_id: 726.0
# Row 211 - disease_name: cognitive_disorder
# Row 211 - biomarkerType: metabolite
# Row 212 - breed_name: Border_Collie
# Row 212 - biomarker_id: 2433.0
# Row 212 - disease_name: intestinal_disorder
# Row 212 - biomarkerType: protein
# Row 213 - breed_name: Border_Collie
# Row 213 - biomarker_id: 2436.0
# Row 213 - disease_name: squamous_cell_carcinoma
# Row 213 - biomarkerType: protein
# Row 214 - breed_name: Border_Collie
# Row 214 - biomarker_id: 2443.0
# Row 214 - disease_name: intestinal_disorder
# Row 214 - biomarkerType: protein
# Row 215 - breed_name: Border_Collie
# Row 215 - biomarker_id: 2453.0
# Row 215 - disease_name: intestinal_disorder
# Row 215 - biomarkerType: protein
# Row 216 - breed_name: Border_Collie
# Row 216 - biomarker_id: 2455.0
# Row 216 - disease_name: intestinal_disorder
# Row 216 - biomarkerType: protein
# Row 217 - breed_name: Border_Collie
# Row 217 - biomarker_id: 2456.0
# Row 217 - disease_name: chronic_kidney_disease
# Row 217 - biomarkerType: protein
# Row 218 - breed_name: Border_Collie
# Row 218 - biomarker_id: 1020.0
# Row 218 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 218 - biomarkerType: miRNA
# Row 219 - breed_name: Border_Collie
# Row 219 - biomarker_id: 1021.0
# Row 219 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 219 - biomarkerType: miRNA
# Row 220 - breed_name: Border_Collie
# Row 220 - biomarker_id: 1022.0
# Row 220 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 220 - biomarkerType: miRNA
# Row 221 - breed_name: Border_Collie
# Row 221 - biomarker_id: 1023.0
# Row 221 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 221 - biomarkerType: miRNA
# Row 222 - breed_name: Border_Collie
# Row 222 - biomarker_id: 1024.0
# Row 222 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 222 - biomarkerType: miRNA
# Row 223 - breed_name: Border_Collie
# Row 223 - biomarker_id: 1025.0
# Row 223 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 223 - biomarkerType: miRNA
# Row 224 - breed_name: Border_Collie
# Row 224 - biomarker_id: 2460.0
# Row 224 - disease_name: intestinal_disorder
# Row 224 - biomarkerType: protein
# Row 225 - breed_name: Border_Collie
# Row 225 - biomarker_id: 2461.0
# Row 225 - disease_name: intestinal_disorder
# Row 225 - biomarkerType: protein
# Row 226 - breed_name: Border_Collie
# Row 226 - biomarker_id: 2167.0
# Row 226 - disease_name: intestinal_disorder
# Row 226 - biomarkerType: protein
# Row 227 - breed_name: Border_Collie
# Row 227 - biomarker_id: 2168.0
# Row 227 - disease_name: intestinal_disorder
# Row 227 - biomarkerType: protein
# Row 228 - breed_name: Border_Collie
# Row 228 - biomarker_id: 2170.0
# Row 228 - disease_name: intestinal_disorder
# Row 228 - biomarkerType: protein
# Row 229 - breed_name: Border_Collie
# Row 229 - biomarker_id: 2176.0
# Row 229 - disease_name: lung_adenocarcinoma
# Row 229 - biomarkerType: protein
# Row 230 - breed_name: Border_Collie
# Row 230 - biomarker_id: 2179.0
# Row 230 - disease_name: intestinal_disorder
# Row 230 - biomarkerType: protein
# Row 231 - breed_name: Border_Collie
# Row 231 - biomarker_id: 2189.0
# Row 231 - disease_name: intestinal_disorder
# Row 231 - biomarkerType: protein
# Row 232 - breed_name: Border_Collie
# Row 232 - biomarker_id: 2198.0
# Row 232 - disease_name: intestinal_disorder
# Row 232 - biomarkerType: protein
# Row 233 - breed_name: Border_Collie
# Row 233 - biomarker_id: 2206.0
# Row 233 - disease_name: intestinal_disorder
# Row 233 - biomarkerType: protein
# Row 234 - breed_name: Border_Collie
# Row 234 - biomarker_id: 2429.0
# Row 234 - disease_name: intestinal_disorder
# Row 234 - biomarkerType: protein
# Row 235 - breed_name: Border_Collie
# Row 235 - biomarker_id: 2225.0
# Row 235 - disease_name: intestinal_disorder
# Row 235 - biomarkerType: protein
# Row 236 - breed_name: Border_Collie
# Row 236 - biomarker_id: 2234.0
# Row 236 - disease_name: intestinal_disorder
# Row 236 - biomarkerType: protein
# Row 237 - breed_name: Border_Collie
# Row 237 - biomarker_id: 2235.0
# Row 237 - disease_name: intestinal_disorder
# Row 237 - biomarkerType: protein
# Row 238 - breed_name: Border_Collie
# Row 238 - biomarker_id: 679.0
# Row 238 - disease_name: urinary_bladder_cancer
# Row 238 - biomarkerType: metabolite
# Row 239 - breed_name: Border_Collie
# Row 239 - biomarker_id: 2240.0
# Row 239 - disease_name: intestinal_disorder
# Row 239 - biomarkerType: protein
# Row 240 - breed_name: Border_Collie
# Row 240 - biomarker_id: 2250.0
# Row 240 - disease_name: intestinal_disorder
# Row 240 - biomarkerType: protein
# Row 241 - breed_name: Border_Collie
# Row 241 - biomarker_id: 186.0
# Row 241 - disease_name: aging
# Row 241 - biomarkerType: gene
# Row 242 - breed_name: Border_Collie
# Row 242 - biomarker_id: 186.0
# Row 242 - disease_name: aging
# Row 242 - biomarkerType: gene
# Row 243 - breed_name: Border_Collie
# Row 243 - biomarker_id: 2267.0
# Row 243 - disease_name: chronic_kidney_disease
# Row 243 - biomarkerType: protein
# Row 244 - breed_name: Border_Collie
# Row 244 - biomarker_id: 2292.0
# Row 244 - disease_name: intestinal_disorder
# Row 244 - biomarkerType: protein
# Row 245 - breed_name: Border_Collie
# Row 245 - biomarker_id: 686.0
# Row 245 - disease_name: acute_pancreatitis
# Row 245 - biomarkerType: metabolite
# Row 246 - breed_name: Border_Collie
# Row 246 - biomarker_id: 2374.0
# Row 246 - disease_name: osteosarcoma
# Row 246 - biomarkerType: protein
# Row 247 - breed_name: Border_Collie
# Row 247 - biomarker_id: 2378.0
# Row 247 - disease_name: intestinal_disorder
# Row 247 - biomarkerType: protein
# Row 248 - breed_name: Border_Collie
# Row 248 - biomarker_id: 2383.0
# Row 248 - disease_name: acute_kidney_failure
# Row 248 - biomarkerType: protein
# Row 249 - breed_name: Border_Collie
# Row 249 - biomarker_id: 2384.0
# Row 249 - disease_name: MVP1
# Row 249 - biomarkerType: protein
# Row 250 - breed_name: Border_Collie
# Row 250 - biomarker_id: 2389.0
# Row 250 - disease_name: acute_kidney_failure
# Row 250 - biomarkerType: protein
# Row 251 - breed_name: Border_Collie
# Row 251 - biomarker_id: 1065.0
# Row 251 - disease_name: melanoma
# Row 251 - biomarkerType: miRNA
# Row 252 - breed_name: Border_Collie
# Row 252 - biomarker_id: 1018.0
# Row 252 - disease_name: melanoma
# Row 252 - biomarkerType: miRNA
# Row 253 - breed_name: Border_Collie
# Row 253 - biomarker_id: 1066.0
# Row 253 - disease_name: melanoma
# Row 253 - biomarkerType: miRNA
# Row 254 - breed_name: Border_Collie
# Row 254 - biomarker_id: 1067.0
# Row 254 - disease_name: melanoma
# Row 254 - biomarkerType: miRNA
# Row 255 - breed_name: Border_Collie
# Row 255 - biomarker_id: 1068.0
# Row 255 - disease_name: melanoma
# Row 255 - biomarkerType: miRNA
# Row 256 - breed_name: Border_Collie
# Row 256 - biomarker_id: 2394.0
# Row 256 - disease_name: acute_kidney_failure
# Row 256 - biomarkerType: protein
# Row 257 - breed_name: Border_Collie
# Row 257 - biomarker_id: 1069.0
# Row 257 - disease_name: melanoma
# Row 257 - biomarkerType: miRNA
# Row 258 - breed_name: Border_Collie
# Row 258 - biomarker_id: 1070.0
# Row 258 - disease_name: melanoma
# Row 258 - biomarkerType: miRNA
# Row 259 - breed_name: Border_Collie
# Row 259 - biomarker_id: 1071.0
# Row 259 - disease_name: melanoma
# Row 259 - biomarkerType: miRNA
# Row 260 - breed_name: Border_Collie
# Row 260 - biomarker_id: 1072.0
# Row 260 - disease_name: melanoma
# Row 260 - biomarkerType: miRNA
# Row 261 - breed_name: Border_Collie
# Row 261 - biomarker_id: 1073.0
# Row 261 - disease_name: melanoma
# Row 261 - biomarkerType: miRNA
# Row 262 - breed_name: Border_Collie
# Row 262 - biomarker_id: 1074.0
# Row 262 - disease_name: melanoma
# Row 262 - biomarkerType: miRNA
# Row 263 - breed_name: Border_Collie
# Row 263 - biomarker_id: 1075.0
# Row 263 - disease_name: melanoma
# Row 263 - biomarkerType: miRNA
# Row 264 - breed_name: Border_Collie
# Row 264 - biomarker_id: 1076.0
# Row 264 - disease_name: melanoma
# Row 264 - biomarkerType: miRNA
# Row 265 - breed_name: Border_Collie
# Row 265 - biomarker_id: 1077.0
# Row 265 - disease_name: melanoma
# Row 265 - biomarkerType: miRNA
# Row 266 - breed_name: Border_Collie
# Row 266 - biomarker_id: 2395.0
# Row 266 - disease_name: acute_kidney_failure
# Row 266 - biomarkerType: protein
# Row 267 - breed_name: Border_Collie
# Row 267 - biomarker_id: 2396.0
# Row 267 - disease_name: acute_kidney_failure
# Row 267 - biomarkerType: protein
# Row 268 - breed_name: Border_Collie
# Row 268 - biomarker_id: 2397.0
# Row 268 - disease_name: intestinal_disorder
# Row 268 - biomarkerType: protein
# Row 269 - breed_name: Border_Collie
# Row 269 - biomarker_id: 2400.0
# Row 269 - disease_name: intestinal_disorder
# Row 269 - biomarkerType: protein
# Row 270 - breed_name: Border_Collie
# Row 270 - biomarker_id: 2405.0
# Row 270 - disease_name: intestinal_disorder
# Row 270 - biomarkerType: protein
# Row 271 - breed_name: Border_Collie
# Row 271 - biomarker_id: 2408.0
# Row 271 - disease_name: intestinal_disorder
# Row 271 - biomarkerType: protein
# Row 272 - breed_name: Border_Terrier
# Row 272 - biomarker_id: 1020.0
# Row 272 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 272 - biomarkerType: miRNA
# Row 273 - breed_name: Border_Terrier
# Row 273 - biomarker_id: 1020.0
# Row 273 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 273 - biomarkerType: miRNA
# Row 274 - breed_name: Border_Terrier
# Row 274 - biomarker_id: 1021.0
# Row 274 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 274 - biomarkerType: miRNA
# Row 275 - breed_name: Border_Terrier
# Row 275 - biomarker_id: 1021.0
# Row 275 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 275 - biomarkerType: miRNA
# Row 276 - breed_name: Border_Terrier
# Row 276 - biomarker_id: 1022.0
# Row 276 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 276 - biomarkerType: miRNA
# Row 277 - breed_name: Border_Terrier
# Row 277 - biomarker_id: 1022.0
# Row 277 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 277 - biomarkerType: miRNA
# Row 278 - breed_name: Border_Terrier
# Row 278 - biomarker_id: 1023.0
# Row 278 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 278 - biomarkerType: miRNA
# Row 279 - breed_name: Border_Terrier
# Row 279 - biomarker_id: 1023.0
# Row 279 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 279 - biomarkerType: miRNA
# Row 280 - breed_name: Border_Terrier
# Row 280 - biomarker_id: 1024.0
# Row 280 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 280 - biomarkerType: miRNA
# Row 281 - breed_name: Border_Terrier
# Row 281 - biomarker_id: 1024.0
# Row 281 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 281 - biomarkerType: miRNA
# Row 282 - breed_name: Border_Terrier
# Row 282 - biomarker_id: 1025.0
# Row 282 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 282 - biomarkerType: miRNA
# Row 283 - breed_name: Border_Terrier
# Row 283 - biomarker_id: 1025.0
# Row 283 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 283 - biomarkerType: miRNA
# Row 284 - breed_name: Border_Terrier
# Row 284 - biomarker_id: 2171.0
# Row 284 - disease_name: melanoma
# Row 284 - biomarkerType: protein
# Row 285 - breed_name: Border_Terrier
# Row 285 - biomarker_id: 2260.0
# Row 285 - disease_name: intestinal_disorder
# Row 285 - biomarkerType: protein
# Row 286 - breed_name: Border_Terrier
# Row 286 - biomarker_id: 2384.0
# Row 286 - disease_name: MVP1
# Row 286 - biomarkerType: protein
# Row 287 - breed_name: Borzoi
# Row 287 - biomarker_id: biomarker_287
# Row 287 - disease_name: disease_287
# Row 287 - biomarkerType: None
# Row 288 - breed_name: Boston_Terrier
# Row 288 - biomarker_id: 2442.0
# Row 288 - disease_name: meningioma
# Row 288 - biomarkerType: protein
# Row 289 - breed_name: Boston_Terrier
# Row 289 - biomarker_id: 2253.0
# Row 289 - disease_name: obstructive_lung_disease
# Row 289 - biomarkerType: protein
# Row 290 - breed_name: Boston_Terrier
# Row 290 - biomarker_id: 2336.0
# Row 290 - disease_name: neoplasm
# Row 290 - biomarkerType: protein
# Row 291 - breed_name: Boston_Terrier
# Row 291 - biomarker_id: 691.0
# Row 291 - disease_name: lymphocytic_colitis
# Row 291 - biomarkerType: metabolite
# Row 292 - breed_name: Bouvier_des_Flandres
# Row 292 - biomarker_id: biomarker_292
# Row 292 - disease_name: disease_292
# Row 292 - biomarkerType: None
# Row 293 - breed_name: Boxer
# Row 293 - biomarker_id: biomarker_293
# Row 293 - disease_name: disease_293
# Row 293 - biomarkerType: None
# Row 294 - breed_name: Boykin_Spaniel
# Row 294 - biomarker_id: biomarker_294
# Row 294 - disease_name: disease_294
# Row 294 - biomarkerType: None
# Row 295 - breed_name: Bracco_Italiano
# Row 295 - biomarker_id: biomarker_295
# Row 295 - disease_name: disease_295
# Row 295 - biomarkerType: None
# Row 296 - breed_name: Braque_du_Bourbonnais
# Row 296 - biomarker_id: biomarker_296
# Row 296 - disease_name: disease_296
# Row 296 - biomarkerType: None
# Row 297 - breed_name: Braque_Francais_Pyrenean
# Row 297 - biomarker_id: biomarker_297
# Row 297 - disease_name: disease_297
# Row 297 - biomarkerType: None
# Row 298 - breed_name: Briard
# Row 298 - biomarker_id: biomarker_298
# Row 298 - disease_name: disease_298
# Row 298 - biomarkerType: None
# Row 299 - breed_name: Brittany
# Row 299 - biomarker_id: 686.0
# Row 299 - disease_name: acute_pancreatitis
# Row 299 - biomarkerType: metabolite
# Row 300 - breed_name: Broholmer
# Row 300 - biomarker_id: biomarker_300
# Row 300 - disease_name: disease_300
# Row 300 - biomarkerType: None
# Row 301 - breed_name: Brussels_Griffon
# Row 301 - biomarker_id: 2403.0
# Row 301 - disease_name: kidney_disorder
# Row 301 - biomarkerType: protein
# Row 302 - breed_name: Bull_Terrier
# Row 302 - biomarker_id: biomarker_302
# Row 302 - disease_name: disease_302
# Row 302 - biomarkerType: None
# Row 303 - breed_name: Bulldog
# Row 303 - biomarker_id: biomarker_303
# Row 303 - disease_name: disease_303
# Row 303 - biomarkerType: None
# Row 304 - breed_name: Bullmastiff
# Row 304 - biomarker_id: 1062.0
# Row 304 - disease_name: osteosarcoma
# Row 304 - biomarkerType: miRNA
# Row 305 - breed_name: Bullmastiff
# Row 305 - biomarker_id: 1063.0
# Row 305 - disease_name: osteosarcoma
# Row 305 - biomarkerType: miRNA
# Row 306 - breed_name: Bullmastiff
# Row 306 - biomarker_id: 2393.0
# Row 306 - disease_name: renal_cell_carcinoma
# Row 306 - biomarkerType: protein
# Row 307 - breed_name: Cairn_Terrier
# Row 307 - biomarker_id: 679.0
# Row 307 - disease_name: urinary_bladder_cancer
# Row 307 - biomarkerType: metabolite
# Row 308 - breed_name: Cairn_Terrier
# Row 308 - biomarker_id: 2374.0
# Row 308 - disease_name: osteosarcoma
# Row 308 - biomarkerType: protein
# Row 309 - breed_name: Canaan_Dog
# Row 309 - biomarker_id: biomarker_309
# Row 309 - disease_name: disease_309
# Row 309 - biomarkerType: None
# Row 310 - breed_name: Cane_Corso
# Row 310 - biomarker_id: biomarker_310
# Row 310 - disease_name: disease_310
# Row 310 - biomarkerType: None
# Row 311 - breed_name: Cardigan_Welsh_Corgi
# Row 311 - biomarker_id: 2418.0
# Row 311 - disease_name: meningoencephalitis
# Row 311 - biomarkerType: protein
# Row 312 - breed_name: Cardigan_Welsh_Corgi
# Row 312 - biomarker_id: 2176.0
# Row 312 - disease_name: lung_adenocarcinoma
# Row 312 - biomarkerType: protein
# Row 313 - breed_name: Cardigan_Welsh_Corgi
# Row 313 - biomarker_id: 2269.0
# Row 313 - disease_name: chronic_kidney_disease
# Row 313 - biomarkerType: protein
# Row 314 - breed_name: Carolina_Dog
# Row 314 - biomarker_id: biomarker_314
# Row 314 - disease_name: disease_314
# Row 314 - biomarkerType: None
# Row 315 - breed_name: Catahoula_Leopard_Dog
# Row 315 - biomarker_id: biomarker_315
# Row 315 - disease_name: disease_315
# Row 315 - biomarkerType: None
# Row 316 - breed_name: Caucasian_Shepherd_Dog
# Row 316 - biomarker_id: biomarker_316
# Row 316 - disease_name: disease_316
# Row 316 - biomarkerType: None
# Row 317 - breed_name: Cavalier_King_Charles_Spaniel
# Row 317 - biomarker_id: 2435.0
# Row 317 - disease_name: mitral_valve_prolapse%2C_myxomatous_3
# Row 317 - biomarkerType: protein
# Row 318 - breed_name: Cavalier_King_Charles_Spaniel
# Row 318 - biomarker_id: 1020.0
# Row 318 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 318 - biomarkerType: miRNA
# Row 319 - breed_name: Cavalier_King_Charles_Spaniel
# Row 319 - biomarker_id: 1021.0
# Row 319 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 319 - biomarkerType: miRNA
# Row 320 - breed_name: Cavalier_King_Charles_Spaniel
# Row 320 - biomarker_id: 1022.0
# Row 320 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 320 - biomarkerType: miRNA
# Row 321 - breed_name: Cavalier_King_Charles_Spaniel
# Row 321 - biomarker_id: 1023.0
# Row 321 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 321 - biomarkerType: miRNA
# Row 322 - breed_name: Cavalier_King_Charles_Spaniel
# Row 322 - biomarker_id: 1024.0
# Row 322 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 322 - biomarkerType: miRNA
# Row 323 - breed_name: Cavalier_King_Charles_Spaniel
# Row 323 - biomarker_id: 1025.0
# Row 323 - disease_name: gastric_neoplasm%7Cintestinal_disorder
# Row 323 - biomarkerType: miRNA
# Row 324 - breed_name: Cavalier_King_Charles_Spaniel
# Row 324 - biomarker_id: 679.0
# Row 324 - disease_name: urinary_bladder_cancer
# Row 324 - biomarkerType: metabolite
# Row 325 - breed_name: Cavalier_King_Charles_Spaniel
# Row 325 - biomarker_id: 2253.0
# Row 325 - disease_name: obstructive_lung_disease
# Row 325 - biomarkerType: protein
# Row 326 - breed_name: Cavalier_King_Charles_Spaniel
# Row 326 - biomarker_id: 2266.0
# Row 326 - disease_name: diabetes_mellitus
# Row 326 - biomarkerType: metabolite
# ...
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('3.9−15.8 kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('10.4 ± 3.5 years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('26 ± 19 kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('average：9years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('13±2.98 years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('4-18years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('1.36-3.5kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('0.27-17.58years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('6.2-13.5years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('6.8-34.5kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('0.3 - 14.0years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('normal group(year): 2-7, MMVD group(year): 5-13,  MMVD with CHF(year): 8-13', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('normal group(kg): 10-36; MMVD group(kg): 8-40, MMVD with CHF(kg):5-13', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('the mean age for dogs with polypoid cystitis and TCC was 9.6 ± 3.7 and 9.7 ± 2.4 years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('3-14.6years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('28-32kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('2–74 months', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('1.5–8.4 kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('1-13years;average:7 years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('8-17years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('7.8 ± 4.6 years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('4.7-12.8 years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('2.5-14.3 kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('3-7.4 years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('2.2-4.2kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('59–73 days', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('0.59 ± 0.23 kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('3–11 years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('11–42 kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('0.5-11years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('3.5-38kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('2-8years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('12.5-30kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('1-12years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('4.7-79kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('5-13years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('5.4-57.7 kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('12.83 ± 2.01years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('6-15 years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('10-15years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('12.83years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('11-13years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('0.25-18years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('2-16years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('3.0-15.0years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('2.08-14.04kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('8-15years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('1.08-8.88years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('5.75-12.53kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('8-12years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('2-21years', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# C:\Users\agavr\AppData\Local\Programs\Python\Python310\lib\site-packages\rdflib\term.py:1620: UserWarning: Serializing weird numerical rdflib.term.Literal('1.2-39.4kg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
#   warnings.warn(f"Serializing weird numerical {self!r}")
# Serialization error: "http://example.org/dogbreed#gastric_neoplasm|intestinal_disorder" does not look like a valid URI, I cannot serialize this as N3/Turtle. Perhaps you wanted to urlencode it?
